# %% [markdown]
# 1. For scraping specific HTML tags along with titles and meta description

# %%
#Importing libraries
from bs4 import BeautifulSoup
import urllib
from urllib import request
import urllib.request as ur

# %%
# Getting input for webiste from user
urlinput = input("Enter url :")
print(" This is the website link that you entered", urlinput)

# For extracting specific tags from webpage
def getTags(tag):
  s = ur.urlopen(urlinput)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

# For extracting specific title & meta description from webpage
def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    #----- Extracting Title from website ------#
    title = soup.title.string
    print ('Website Title is :', title)
    #-----  Extracting Meta description from website ------#
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            #print ('NAME    :',tag.attrs['name'].lower())
            print ('CONTENT :',tag.attrs['content'])

#------------- Main ---------------#
if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('h1')
  for tag in tags:
     print(tag) # display tags 
     print(tag.contents) # display contents of the tags
# Out:
# Enter url : https://www.shadowfox.in/
#  This is the website link that you entered https://www.shadowfox.in/
# Website Title is : ShadowFox
# CONTENT : Transform your learning experience with ShadowFox Virtual Internship Program. Gain practical skills through industry-focused curriculum and hands-on projects. Join us now!
# CONTENT : ShadowFox, Virtual Internship Program, internship, industry-focused curriculum, hands-on projects, practical skills
# <h1>Welcome to ShadowFox</h1>
# ['Welcome to ShadowFox']
# <h1 class="title text-center">WHO ARE WE?</h1>
# ['WHO ARE WE?']
# <h1 class="title">WHY CHOOSE US?</h1>
# ['WHY CHOOSE US?']
# <h1>Internships that we offer</h1>
# ['Internships that we offer']

# %% [markdown]
# 2. For extracting specific tags, all heading tags from h1-h6 along with titles and meta description

# %%
# Importing libraries
from bs4 import BeautifulSoup
import urllib
from urllib import request
import urllib.request as ur

# %%
# Getting input for webiste from user
url_input = input("Enter url :")
print(" This is the website link that you entered", url_input)


# For extracting specific tags from webpage
def getTags(tag):
  s = ur.urlopen(url_input)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

# For extracting all h1-h6 heading tags from webpage
def headingTags(headingtags):
  h = ur.urlopen(url_input)
  soup = BeautifulSoup(h.read())
  print("List of headings from headingtags function h1, h2, h3, h4, h5, h6 :")
  for heading in soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"]):
    print(heading.name + ' ' + heading.text.strip())

# For extracting specific title & meta description from webpage
def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    #----- Extracting Title from website ------#
    title = soup.title.string
    print ('Website Title is :', title)
    #-----  Extracting Meta description from website ------#
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            #print ('NAME    :',tag.attrs['name'].lower())
            print ('CONTENT :',tag.attrs['content'])

#------------- Main ---------------#
if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('p')
  headtags = headingTags('h1')
  for tag in tags:
     print(" Here are the tags from getTags function:", tag.contents)
# Out:
# Enter url : https://www.shadowfox.in/
#  This is the website link that you entered https://www.shadowfox.in/
# Website Title is : ShadowFox
# CONTENT : Transform your learning experience with ShadowFox Virtual Internship Program. Gain practical skills through industry-focused curriculum and hands-on projects. Join us now!
# CONTENT : ShadowFox, Virtual Internship Program, internship, industry-focused curriculum, hands-on projects, practical skills
# List of headings from headingtags function h1, h2, h3, h4, h5, h6 :
# h1 Welcome to ShadowFox
# h4 We are
# h1 WHO ARE WE?
# h1 WHY CHOOSE US?
# h4 Networking
# h4 Mentorship
# h4 Swags and Goodies
# h1 Internships that we offer
# h3 Data Science
# h3 Python Development
# h3 Web Development
# h3 UI/UX Design
# h3 AI/ML
# h3 Cyber Security
# h3 Android App Development
# h3 Java Development
# h2 Frequently Asked Questions
# h3 Support
# h3 Follow Us
# h3 Contact
#  Here are the tags from getTags function: ["Founded on the belief that knowledge transforms lives, Shadow Fox emerged from a passion for education and innovation. Our journey is a commitment to turning aspirations into accomplishments in a unique digital learning adventure. At Shadow Fox, we appreciate every milestone and motivate learners with goodies as tokens of accomplishment for completing tasks. Because we understand that the learning journey deserves joy, encouragement, and a tangible 'Well done!'"]
#  Here are the tags from getTags function: ['Connect with a diverse community of learners. Our networking \r\n                        opportunities go beyond the virtual classroom, opening doors for collaboration \r\n                        and potential career growth.']
#  Here are the tags from getTags function: ['Explore personalized guidance in our mentorship program, where \r\n                        dedicated mentors support you throughout your learning journey. Receive \r\n                        tailored advice for a well-rounded education, ensuring practical wisdom and \r\n                        success tools in a one-on-one setting.']
#  Here are the tags from getTags function: ["Celebrate your achievements with exclusive Shadow Fox merchandise \r\n                        and goodies. It's our way of appreciating your dedication and creating a \r\n                        positive, rewarding learning environment."]
#  Here are the tags from getTags function: ['Embark on a Learning Journey: Unleash Your Potential in Our Virtual Internship Programs!']
#  Here are the tags from getTags function: ['Explore our Data Science program, delving into data analysis, machine learning, and predictive modeling. Apply your skills to real-world projects that drive meaningful insights']
#  Here are the tags from getTags function: ['Enroll in our Python Development program to master coding efficiency and build scalable applications. Dive into hands-on projects that harness the power of Python for diverse applications.']
#  Here are the tags from getTags function: ['Embark on your journey in Web Development with our comprehensive program. Acquire hands-on experience in crafting responsive and user-friendly websites using the latest tools and frameworks.']
#  Here are the tags from getTags function: ['Shape the digital experience with our UI/UX Design program. Learn design thinking, user research, and interactive prototyping to create engaging and intuitive digital interfaces.']
#  Here are the tags from getTags function: ['Join our AI/ML program and unlock the potential of Artificial Intelligence and Machine Learning. Immerse yourself in cutting-edge technologies, algorithms, and applications that shape intelligent systems.']
#  Here are the tags from getTags function: ['Explore our Cybersecurity program to learn the essentials of safeguarding digital landscapes. Identify vulnerabilities, develop strategies, and protect against evolving cyber threats in this critical and dynamic field.']
#  Here are the tags from getTags function: ['Embark on your journey in Android App Development with our specialized program. Master the skills required to build innovative and user-friendly Android applications that cater to diverse user needs.']
#  Here are the tags from getTags function: ['Embark on your journey in Java Development with our specialized program. Master the fundamentals of Java programming language and build robust, scalable applications for various platforms.']
#  Here are the tags from getTags function: ['Choose ShadowFox for a holistic learning experience. Our industry-focused \r\n                        curriculum, led by experienced instructors, ensures you gain practical skills. With hands-on \r\n                        projects, flexible learning, and a supportive community, we go beyond traditional education.']
#  Here are the tags from getTags function: ['To apply for a ShadowFox Virtual Internship Program, fill out the interest form corresponding to \r\n                        your domain. Alternatively, you can submit your application through the AICTE Internship \r\n                        portal, where we also source interns.']
#  Here are the tags from getTags function: ['ShadowFox VIP - Stands for ShadowFox Virtual Internship Program and is a 1 month program']
#  Here are the tags from getTags function: ['You can expect to receive a confirmation from our end approximately one week before \r\n                        the commencement of your tenure period.']
#  Here are the tags from getTags function: [' There are 3 Levels in total, Level - 1(Easy Tasks),Level - 2(Intermediate tasks) and Level - 3(Realtime projects)']
#  Here are the tags from getTags function: ['Yes, we do issue physical certificates for individuals who successfully complete tasks \r\n                        beyond the Level-1 threshold.']
#  Here are the tags from getTags function: ["Yes, ShadowFox VIP is a completely free internship program. However, there is a documentation and delivery fee for each level, although it is not mandatory to pay if you don't need the swags."]
#  Here are the tags from getTags function: [<img alt="" class="img-reduce" src="images/img-Email.svg"/>, <a href="mailto:hr@shadowfox.in"> hr@shadowfox.in</a>]
#  Here are the tags from getTags function: [<img alt="" class="img-reduce" src="images/img-Phone.svg"/>, <a href="tel:+918095776765"> +91 8095776765</a>]
#  Here are the tags from getTags function: [<img alt="" class="img-reduce" src="images/img-Phone.svg"/>, <a href="tel:+917604963297"> +91 7604963297</a>]
#  Here are the tags from getTags function: ['Made with ♥ by ShadowFox']
#  Here are the tags from getTags function: ['© Copyright 2023 ShadowFox. All Rights Reserved.']

# %% [markdown]
# 3. For extracting ALT tags (Image Alter tags)

# %%
import urllib.request as ur

url_input = input("Enter url :")
print("The website link that you entered is:", url_input)

def alt_tag():
  url =  ur.urlopen(url_input)
  htmlSource = url.read()
  url.close()
  soup = BeautifulSoup(htmlSource)
  print('\n The alt tag along with the text in the web page')
  print(soup.find_all('img',alt= True))
  


#------------- Main ---------------#
if __name__ == '__main__':
  alt_tag()
# Out:
# Enter url : https://www.shadowfox.in/
# The website link that you entered is: https://www.shadowfox.in/
#
#  The alt tag along with the text in the web page
# [<img alt="///" src="images/img-Nav.svg"/>, <img alt="Organization Logo" class="img-fluid" src="images/bannerimg.png" width="400px"/>, <img alt="Wave Image" class="bottom-img" src="images/wave1.png"/>, <img alt="data-science" loading="lazy" src="images/ds1.png" width="180px"/>, <img alt="python-development" loading="lazy" src="images/py1.png" width="180px"/>, <img alt="web-development" loading="lazy" src="images/webdev1.png" width="150px"/>, <img alt="ui/ux-design" loading="lazy" src="images/uiux1.png" width="150px"/>, <img alt="ai" loading="lazy" src="images/aiml1.png" width="150px"/>, <img alt="cyber-security" loading="lazy" src="images/cs1.png" width="150px"/>, <img alt="android-app-development" loading="lazy" src="images/ad1.png" width="200px"/>, <img alt="java-development" loading="lazy" src="images/jd1.png" width="200px"/>, <img alt="LinkedIn" class="icon-hover img-reduce" src="images/img-Linkedin.svg"/>, <img alt="Instagram" class="icon-hover img-reduce" src="images/img-Instagram.svg"/>, <img alt="Discord" class="icon-hover img-reduce" src="images/img-Discord.svg"/>, <img alt="X" class="icon-hover img-reduce" src="images/img-X.svg"/>, <img alt="" class="img-reduce" src="images/img-Email.svg"/>, <img alt="" class="img-reduce" src="images/img-Phone.svg"/>, <img alt="" class="img-reduce" src="images/img-Phone.svg"/>]

# %%
# For reviewing alt tags in seperate lines
soup.find_all('img',alt= True)
# Out:
# [<img alt="///" src="images/img-Nav.svg"/>,
#  <img alt="Organization Logo" class="img-fluid" src="images/bannerimg.png" width="400px"/>,
#  <img alt="Wave Image" class="bottom-img" src="images/wave1.png"/>,
#  <img alt="data-science" loading="lazy" src="images/ds1.png" width="180px"/>,
#  <img alt="python-development" loading="lazy" src="images/py1.png" width="180px"/>,
#  <img alt="web-development" loading="lazy" src="images/webdev1.png" width="150px"/>,
#  <img alt="ui/ux-design" loading="lazy" src="images/uiux1.png" width="150px"/>,
#  <img alt="ai" loading="lazy" src="images/aiml1.png" width="150px"/>,
#  <img alt="cyber-security" loading="lazy" src="images/cs1.png" width="150px"/>,
#  <img alt="android-app-development" loading="lazy" src="images/ad1.png" width="200px"/>,
#  <img alt="java-development" loading="lazy" src="images/jd1.png" width="200px"/>,
#  <img alt="LinkedIn" class="icon-hover img-reduce" src="images/img-Linkedin.svg"/>,
#  <img alt="Instagram" class="icon-hover img-reduce" src="images/img-Instagram.svg"/>,
#  <img alt="Discord" class="icon-hover img-reduce" src="images/img-Discord.svg"/>,
#  <img alt="X" class="icon-hover img-reduce" src="images/img-X.svg"/>,
#  <img alt="" class="img-reduce" src="images/img-Email.svg"/>,
#  <img alt="" class="img-reduce" src="images/img-Phone.svg"/>,
#  <img alt="" class="img-reduce" src="images/img-Phone.svg"/>]

# %% [markdown]
# 4. For counting words inside a web page

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation

# Getting content from web page
r = requests.get("https://www.shadowfox.in/")
soup = BeautifulSoup(r.content)

# For getting words within paragrphs
text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
count_paragraph = Counter((x.rstrip(punctuation).lower() for y in text_paragraph for x in y.split()))

# For getting words inside div tags
text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))
count_div = Counter((x.rstrip(punctuation).lower() for y in text_div for x in y.split()))

# Adding two counters for getting a list with words count (from most to less common)
total = count_div + count_paragraph
list_most_common_words = total.most_common()
# Out:
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_5332\4021331692.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_5332\4021331692.py:15: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))

# %%
# Total words inside a webpage
len(total)
# Out:
# 339

# %%
# List of common words
list_most_common_words
# Out:
# [('and', 83),
#  ('a', 54),
#  ('the', 49),
#  ('our', 47),
#  ('program', 42),
#  ('for', 38),
#  ('in', 38),
#  ('to', 37),
#  ('your', 35),
#  ('with', 32),
#  ('learning', 29),
#  ('of', 27),
#  ('shadowfox', 24),
#  ('apply', 23),
#  ('journey', 22),
#  ('we', 20),
#  ('that', 20),
#  ('development', 20),
#  ('is', 19),
#  ('you', 17),
#  ('now', 16),
#  ('', 16),
#  ('applications', 15),
#  ('internship', 15),
#  ('on', 14),
#  ('digital', 13),
#  ('shadow', 12),
#  ('fox', 12),
#  ('virtual', 12),
#  ('projects', 12),
#  ('education', 11),
#  ('goodies', 11),
#  ('into', 10),
#  ('tasks', 10),
#  ('diverse', 10),
#  ('beyond', 10),
#  ('explore', 10),
#  ('embark', 10),
#  ('skills', 9),
#  ('master', 9),
#  ('build', 9),
#  ('hands-on', 9),
#  ('experience', 9),
#  ('level', 9),
#  ('us', 8),
#  ('contact', 8),
#  ('learners', 8),
#  ('potential', 8),
#  ('data', 8),
#  ('python', 8),
#  ('design', 8),
#  ('android', 8),
#  ('java', 8),
#  ('+91', 8),
#  ('are', 7),
#  ('from', 7),
#  ('networking', 7),
#  ('community', 7),
#  ('go', 7),
#  ('mentorship', 7),
#  ('where', 7),
#  ('support', 7),
#  ('receive', 7),
#  ('practical', 7),
#  ('tools', 7),
#  ('vip', 7),
#  ('there', 7),
#  ('swags', 6),
#  ('machine', 6),
#  ('scalable', 6),
#  ('user-friendly', 6),
#  ('shape', 6),
#  ('learn', 6),
#  ('user', 6),
#  ('specialized', 6),
#  ('can', 6),
#  ('yes', 6),
#  ('science', 5),
#  ('web', 5),
#  ('ui/ux', 5),
#  ('ai/ml', 5),
#  ('cyber', 5),
#  ('app', 5),
#  ('by', 5),
#  ('who', 4),
#  ('founded', 4),
#  ('belief', 4),
#  ('knowledge', 4),
#  ('transforms', 4),
#  ('lives', 4),
#  ('emerged', 4),
#  ('passion', 4),
#  ('innovation', 4),
#  ('commitment', 4),
#  ('turning', 4),
#  ('aspirations', 4),
#  ('accomplishments', 4),
#  ('unique', 4),
#  ('adventure', 4),
#  ('at', 4),
#  ('appreciate', 4),
#  ('every', 4),
#  ('milestone', 4),
#  ('motivate', 4),
#  ('as', 4),
#  ('tokens', 4),
#  ('accomplishment', 4),
#  ('completing', 4),
#  ('because', 4),
#  ('understand', 4),
#  ('deserves', 4),
#  ('joy', 4),
#  ('encouragement', 4),
#  ('tangible', 4),
#  ("'well", 4),
#  ('done', 4),
#  ('choose', 4),
#  ('connect', 4),
#  ('opportunities', 4),
#  ('classroom', 4),
#  ('opening', 4),
#  ('doors', 4),
#  ('collaboration', 4),
#  ('career', 4),
#  ('growth', 4),
#  ('personalized', 4),
#  ('guidance', 4),
#  ('dedicated', 4),
#  ('mentors', 4),
#  ('throughout', 4),
#  ('tailored', 4),
#  ('advice', 4),
#  ('well-rounded', 4),
#  ('ensuring', 4),
#  ('wisdom', 4),
#  ('success', 4),
#  ('one-on-one', 4),
#  ('setting', 4),
#  ('celebrate', 4),
#  ('achievements', 4),
#  ('exclusive', 4),
#  ('merchandise', 4),
#  ("it's", 4),
#  ('way', 4),
#  ('appreciating', 4),
#  ('dedication', 4),
#  ('creating', 4),
#  ('positive', 4),
#  ('rewarding', 4),
#  ('environment', 4),
#  ('this', 4),
#  ('various', 4),
#  ('levels', 4),
#  ('total', 4),
#  ('do', 4),
#  ('physical', 4),
#  ('certificates', 4),
#  ('free', 4),
#  ('hr@shadowfox.in', 4),
#  ('8095776765', 4),
#  ('7604963297', 4),
#  ('delving', 3),
#  ('analysis', 3),
#  ('predictive', 3),
#  ('modeling', 3),
#  ('real-world', 3),
#  ('drive', 3),
#  ('meaningful', 3),
#  ('insights', 3),
#  ('enroll', 3),
#  ('coding', 3),
#  ('efficiency', 3),
#  ('dive', 3),
#  ('harness', 3),
#  ('power', 3),
#  ('comprehensive', 3),
#  ('acquire', 3),
#  ('crafting', 3),
#  ('responsive', 3),
#  ('websites', 3),
#  ('using', 3),
#  ('latest', 3),
#  ('frameworks', 3),
#  ('thinking', 3),
#  ('research', 3),
#  ('interactive', 3),
#  ('prototyping', 3),
#  ('create', 3),
#  ('engaging', 3),
#  ('intuitive', 3),
#  ('interfaces', 3),
#  ('join', 3),
#  ('unlock', 3),
#  ('artificial', 3),
#  ('intelligence', 3),
#  ('immerse', 3),
#  ('yourself', 3),
#  ('cutting-edge', 3),
#  ('technologies', 3),
#  ('algorithms', 3),
#  ('intelligent', 3),
#  ('systems', 3),
#  ('cybersecurity', 3),
#  ('essentials', 3),
#  ('safeguarding', 3),
#  ('landscapes', 3),
#  ('identify', 3),
#  ('vulnerabilities', 3),
#  ('develop', 3),
#  ('strategies', 3),
#  ('protect', 3),
#  ('against', 3),
#  ('evolving', 3),
#  ('threats', 3),
#  ('critical', 3),
#  ('dynamic', 3),
#  ('field', 3),
#  ('required', 3),
#  ('innovative', 3),
#  ('cater', 3),
#  ('needs', 3),
#  ('fundamentals', 3),
#  ('programming', 3),
#  ('language', 3),
#  ('robust', 3),
#  ('platforms', 3),
#  ('holistic', 3),
#  ('industry-focused', 3),
#  ('curriculum', 3),
#  ('led', 3),
#  ('experienced', 3),
#  ('instructors', 3),
#  ('ensures', 3),
#  ('gain', 3),
#  ('flexible', 3),
#  ('supportive', 3),
#  ('traditional', 3),
#  ('how', 3),
#  ('fill', 3),
#  ('out', 3),
#  ('interest', 3),
#  ('form', 3),
#  ('corresponding', 3),
#  ('domain', 3),
#  ('alternatively', 3),
#  ('submit', 3),
#  ('application', 3),
#  ('through', 3),
#  ('aicte', 3),
#  ('portal', 3),
#  ('also', 3),
#  ('source', 3),
#  ('interns', 3),
#  ('stands', 3),
#  ('1', 3),
#  ('month', 3),
#  ('expect', 3),
#  ('confirmation', 3),
#  ('end', 3),
#  ('approximately', 3),
#  ('one', 3),
#  ('week', 3),
#  ('before', 3),
#  ('commencement', 3),
#  ('tenure', 3),
#  ('period', 3),
#  ('3', 3),
#  ('1(easy', 3),
#  ('tasks),level', 3),
#  ('2(intermediate', 3),
#  ('3(realtime', 3),
#  ('issue', 3),
#  ('individuals', 3),
#  ('successfully', 3),
#  ('complete', 3),
#  ('level-1', 3),
#  ('threshold', 3),
#  ('completely', 3),
#  ('however', 3),
#  ('documentation', 3),
#  ('delivery', 3),
#  ('fee', 3),
#  ('each', 3),
#  ('although', 3),
#  ('it', 3),
#  ('not', 3),
#  ('mandatory', 3),
#  ('pay', 3),
#  ('if', 3),
#  ("don't", 3),
#  ('need', 3),
#  ('faq', 3),
#  ('terms', 3),
#  ('conditions', 3),
#  ('help', 3),
#  ('verify', 3),
#  ('follow', 3),
#  ('updated', 3),
#  ('social', 3),
#  ('media', 3),
#  ('links', 3),
#  ('fontawesome', 3),
#  ('icons', 3),
#  ('home', 2),
#  ('about', 2),
#  ('internships', 2),
#  ('welcome', 2),
#  ('why', 2),
#  ('security', 2),
#  ('made', 2),
#  ('♥', 2),
#  ('©', 2),
#  ('copyright', 2),
#  ('2023', 2),
#  ('all', 2),
#  ('rights', 2),
#  ('reserved', 2),
#  ('frequently', 1),
#  ('asked', 1),
#  ('questions', 1),
#  ('might', 1),
#  ('be', 1),
#  ('choice', 1),
#  ('among', 1),
#  ('alternatives', 1),
#  ('what', 1),
#  ('long', 1),
#  ('when', 1),
#  ('will', 1),
#  ('i', 1),
#  ('get', 1),
#  ('offer', 1),
#  ('letter', 1),
#  ('after', 1),
#  ('applying', 1),
#  ('many', 1),
#  ('provide', 1),
#  ('unleash', 1),
#  ('programs', 1)]

# %% [markdown]
# 5. For inspecting Broken links inside a webpage
#
# We want to retrieve the response code 200 if the site is fully functional. We'll get the 404 response code if it's not available.

# %%
# Importing libraries
from bs4 import BeautifulSoup, SoupStrainer
import requests

# Getting URL from user
url = input("Enter your url: ")

def broken_page():
  # For making request to get the URL
  user_req_page = requests.get(url)

  # For getting the response code of given URL
  response_code = str(user_req_page.status_code)

  # For displaying the text of the URL in str
  data =user_req_page.text

  # For using BeautifulSoup to access the built-in methods
  soup = BeautifulSoup(data)

  # Iterate over all links on the given URL with the response code next to it i.e 404 for PAGE NOT FOUND, 200 if website is functional/available
  for link in soup.find_all('a'):
    print(f"Url: {link.get('href')} " + f"| Status Code: {response_code}")


#----- NOTE ------#
# --------- TO VERIFY PAGE NOT FOUND 404 ERROR, enter below web link as a input URL --------#
#https://roine.github.com/p1

#------------- Main ---------------#
if __name__ == '__main__':
  broken_page()

# %% [markdown]
# 6. Extraction of all URLs from a website without duplication

# %%
#---- Importing libraries ----#
import re
import requests
from bs4 import BeautifulSoup

all_links = set() #------ Creating a unique set of links ------#

for i in range(7):
   r = requests.get(("https://www.shadowfox.in/").format(i))
   soup = BeautifulSoup(r.content , "html.parser")
   for link in soup.find_all("a",href=re.compile('/')):
            link = (link.get('href'))
            #----- For the removal of duplicate URLs, We will simply add a link to that set; this assures that it's distinct ------#
            if link not in all_links:
              print(link)
            all_links.add(link)
